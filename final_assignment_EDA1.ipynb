# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasbhosale23/Assignments_by_tejas/blob/main/final_assignment_EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('survey lung cancer.csv')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.shape
# Out:
# (309, 16)

# %%
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %% [markdown]
# **Checking the duplicates and removes duplicates.**

# %%
df.duplicated().sum()
# Out:
# 33

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  276.000000  276.000000      276.000000  276.000000     276.000000
# mean    62.909420    1.543478        1.576087    1.496377       1.507246
# std      8.379355    0.499011        0.495075    0.500895       0.500856
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.750000    1.000000        1.000000    1.000000       1.000000
# 50%     62.500000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       276.000000  276.000000  276.000000  276.000000         276.000000
# mean          1.521739    1.663043    1.547101    1.547101           1.550725
# ...

# %% [markdown]
# Checking for Null values

# %%
df.isna().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %% [markdown]
# **Checking for data types**

# %%
df['GENDER'].value_counts()
# Out:
# GENDER
# M    142
# F    134
# Name: count, dtype: int64

# %%
cat_col = [feature for feature in df.columns if df[feature].dtype == 'O']
cat_col
# Out:
# ['GENDER', 'LUNG_CANCER']

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
num_col = [feature for feature in df.columns if df[feature].dtype != 'O']
num_col
# Out:
# ['AGE',
#  'SMOKING',
#  'YELLOW_FINGERS',
#  'ANXIETY',
#  'PEER_PRESSURE',
#  'CHRONIC DISEASE',
#  'FATIGUE ',
#  'ALLERGY ',
#  'WHEEZING',
#  'ALCOHOL CONSUMING',
#  'COUGHING',
#  'SHORTNESS OF BREATH',
#  'SWALLOWING DIFFICULTY',
#  'CHEST PAIN']

# %% [markdown]
# DATA cleaning

# %%
df['GENDER'].value_counts()
# Out:
# GENDER
# M    142
# F    134
# Name: count, dtype: int64

# %%
df['AGE'].value_counts()
# Out:
# AGE
# 64    18
# 60    16
# 56    16
# 62    16
# 59    15
# 63    15
# 70    14
# 61    14
# 67    11
# 69    10
# 55    10
# 72    10
# 68     9
# 71     9
# 57     9
# 77     9
# 58     8
# 54     7
# 74     6
# 65     5
# 51     5
# 75     5
# 73     4
# 52     4
# 53     4
# 66     4
# 76     3
# 47     3
# 49     3
# 48     2
# 44     2
# 78     2
# 81     2
# 21     1
# 79     1
# 38     1
# 39     1
# 87     1
# 46     1
# Name: count, dtype: int64

# %%
df['SMOKING'].value_counts()
# Out:
# SMOKING
# 2    150
# 1    126
# Name: count, dtype: int64

# %%
df['YELLOW_FINGERS'].value_counts()
# Out:
# YELLOW_FINGERS
# 2    159
# 1    117
# Name: count, dtype: int64

# %%
df['ANXIETY'].value_counts()
# Out:
# ANXIETY
# 1    139
# 2    137
# Name: count, dtype: int64

# %%
df['PEER_PRESSURE'].value_counts()
# Out:
# PEER_PRESSURE
# 2    140
# 1    136
# Name: count, dtype: int64

# %%
df['CHRONIC DISEASE'].value_counts()
# Out:
# CHRONIC DISEASE
# 2    144
# 1    132
# Name: count, dtype: int64

# %%
df["FATIGUE "].value_counts()
# Out:
# FATIGUE
# 2    183
# 1     93
# Name: count, dtype: int64

# %%
df['ALLERGY '].value_counts()
# Out:
# ALLERGY
# 2    151
# 1    125
# Name: count, dtype: int64

# %%
df['WHEEZING'].value_counts()
# Out:
# WHEEZING
# 2    151
# 1    125
# Name: count, dtype: int64

# %%
df['GENDER'] = df['GENDER'].replace({'M': 'Male', 'F': 'Female'})
df['SMOKING'] = df['SMOKING'].replace({2: 'Yes', 1:'No'})
df['YELLOW_FINGERS'] = df['YELLOW_FINGERS'].replace({2: 'Yes', 1: 'No'})
df['ANXIETY'] = df['ANXIETY'].replace({2: 'Yes', 1: 'No'})
df['PEER_PRESSURE'] = df['PEER_PRESSURE'].replace({2: "Yes", 1: "No"})
df['CHRONIC DISEASE'] = df['CHRONIC DISEASE'].replace({2: "Yes", 1: "No"})
df['FATIGUE '] = df['FATIGUE '].replace({2: "Yes", 1: "No"})
df['ALLERGY '] = df['ALLERGY '].replace({2: "Yes", 1: "No"})
df['WHEEZING'] = df['WHEEZING'].replace({2: "Yes", 1: "No"})
df['ALCOHOL CONSUMING'] = df['ALCOHOL CONSUMING'].replace({2: "Yes", 1: "No"})
df['COUGHING'] = df['COUGHING'].replace({2: "Yes", 1: "No"})
df['SHORTNESS OF BREATH'] = df['SHORTNESS OF BREATH'].replace({2: "Yes", 1: "No"})
df['SWALLOWING DIFFICULTY'] = df['SWALLOWING DIFFICULTY'].replace({2: "Yes", 1: "No"})
df['CHEST PAIN'] = df['CHEST PAIN'].replace({2: "Yes", 1: "No"})

# %%
df.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 2  Female   59      No             No      No           Yes              No
# 3    Male   63     Yes            Yes     Yes            No              No
# 4  Female   63      No            Yes      No            No              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 2      Yes       No      Yes                No      Yes                 Yes
# 3       No       No       No               Yes       No                  No
# 4       No       No      Yes                No      Yes                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# ...

# %%
df.describe()
# Out:
#               AGE
# count  276.000000
# mean    62.909420
# std      8.379355
# min     21.000000
# 25%     57.750000
# 50%     62.500000
# 75%     69.000000
# max     87.000000

# %%
genders_with_lung_cancer = df.groupby(['GENDER'])['LUNG_CANCER'].sum().sort_values(ascending=False).reset_index()

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.groupby(['GENDER'])['AGE'].sum().sort_values(ascending=False).reset_index()
# Out:
#    GENDER   AGE
# 0    Male  8918
# 1  Female  8445

# %%
df['AGE']
# Out:
# 0      69
# 1      74
# 2      59
# 3      63
# 4      63
#        ..
# 279    59
# 280    59
# 281    55
# 282    46
# 283    60
# Name: AGE, Length: 276, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    object
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    object
#  3   YELLOW_FINGERS         276 non-null    object
#  4   ANXIETY                276 non-null    object
#  5   PEER_PRESSURE          276 non-null    object
#  6   CHRONIC DISEASE        276 non-null    object
#  7   FATIGUE                276 non-null    object
#  8   ALLERGY                276 non-null    object
#  9   WHEEZING               276 non-null    object
#  10  ALCOHOL CONSUMING      276 non-null    object
#  11  COUGHING               276 non-null    object
#  12  SHORTNESS OF BREATH    276 non-null    object
#  13  SWALLOWING DIFFICULTY  276 non-null    object
# ...

# %%
# univariate analysis

plt.figure(figsize=(10,6))
sns.histplot(df['AGE'], kde=True, color='skyblue')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Insights - Most of the peoples are between age 50-70.

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df['SMOKING'].value_counts()
# Out:
# SMOKING
# Yes    150
# No     126
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='SMOKING', data=df, palette = 'viridis')
plt.title('count of hypertension')
plt.xlabel('hypertension')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Insights - Smoking people are more as compare non smoking peoples.

# %%
df
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0      Male   69      No            Yes     Yes            No              No
# 1      Male   74     Yes             No      No            No             Yes
# 2    Female   59      No             No      No           Yes              No
# 3      Male   63     Yes            Yes     Yes            No              No
# 4    Female   63      No            Yes      No            No              No
# ..      ...  ...     ...            ...     ...           ...             ...
# 279  Female   59      No            Yes     Yes           Yes              No
# 280  Female   59     Yes             No      No            No             Yes
# 281    Male   55     Yes             No      No            No              No
# 282    Male   46      No            Yes     Yes            No              No
# 283    Male   60      No            Yes     Yes            No              No
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='FATIGUE ', y='AGE', data=df)
plt.xlabel('FATIGUE')
plt.ylabel('AGE')
plt.title('violinplot of Age by Fatigue')
plt.show()

# %% [markdown]
# Insights - The plot indicates that fatigue increases in individuals aged 55 to 75. However, it's also observed that there is less fatigue reported in individuals aged 55 to 65.

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='ALLERGY ', y='AGE', data=df)
plt.xlabel('ALLERGY')
plt.ylabel('AGE')
plt.title('violinplot of Age by Allergy')
plt.show()

# %% [markdown]
# Insights - The plot indicates that Allergy increases in individuals aged 52 to 75. However, it's also observed that there is no Allergy reported in individuals aged 55 to 70.

# %%
df
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0      Male   69      No            Yes     Yes            No              No
# 1      Male   74     Yes             No      No            No             Yes
# 2    Female   59      No             No      No           Yes              No
# 3      Male   63     Yes            Yes     Yes            No              No
# 4    Female   63      No            Yes      No            No              No
# ..      ...  ...     ...            ...     ...           ...             ...
# 279  Female   59      No            Yes     Yes           Yes              No
# 280  Female   59     Yes             No      No            No             Yes
# 281    Male   55     Yes             No      No            No              No
# 282    Male   46      No            Yes     Yes            No              No
# 283    Male   60      No            Yes     Yes            No              No
#
# ...

# %%
sns.countplot(x='ANXIETY', data=df)
# Out:
# <Axes: xlabel='ANXIETY', ylabel='count'>

# %%
df.groupby(['GENDER', 'ANXIETY'])['AGE'].mean().sort_values(ascending=False).reset_index()
# Out:
#    GENDER ANXIETY        AGE
# 0    Male     Yes  63.683333
# 1  Female     Yes  63.064935
# 2  Female      No  62.964912
# 3    Male      No  62.158537

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.groupby(['GENDER', 'SMOKING'])['AGE'].mean()
# Out:
# GENDER  SMOKING
# Female  No         64.296875
#         Yes        61.857143
# Male    No         62.838710
#         Yes        62.775000
# Name: AGE, dtype: float64

# %% [markdown]
# Insights - Avg. age of females who are not smoking are more than females who are smoking. While for male, Avg. age is same for both who smoking and

# %%
df.groupby(['GENDER', 'PEER_PRESSURE'])['AGE'].mean()
# Out:
# GENDER  PEER_PRESSURE
# Female  No               62.458333
#         Yes              63.337209
# Male    No               62.659091
#         Yes              63.037037
# Name: AGE, dtype: float64

# %% [markdown]
# Insights : Avg. age of females who are not peer_pressure are equals to who are have peer pressure. However, It is same male also.

# %%
def violin(col):
  fig = px.violin(df, y=col, x='GENDER', box=True, template='plotly_dark')
  return fig.show()

# %%
violin('AGE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
sns.scatterplot(x='ALLERGY', y='AGE', data=df, hue='GENDER')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-97367cf4b48c> in <cell line: 1>()
# ----> 1 sns.scatterplot(x='ALLERGY', y='AGE', data=df, hue='GENDER')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# --> 391         super().__init__(data=data, variables=variables)
#     392
#     393         self.legend = legend
#
# ...

# %%
def scatter(col1, col2):
  fig = px.scatter(df, x=col1, y=col2, color='GENDER', template = 'plotly_dark')
  return fig.show()

# %%
scatter('SMOKING', 'AGE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0      Male   69      No            Yes     Yes            No              No
# 1      Male   74     Yes             No      No            No             Yes
# 2    Female   59      No             No      No           Yes              No
# 3      Male   63     Yes            Yes     Yes            No              No
# 4    Female   63      No            Yes      No            No              No
# ..      ...  ...     ...            ...     ...           ...             ...
# 279  Female   59      No            Yes     Yes           Yes              No
# 280  Female   59     Yes             No      No            No             Yes
# 281    Male   55     Yes             No      No            No              No
# 282    Male   46      No            Yes     Yes            No              No
# 283    Male   60      No            Yes     Yes            No              No
#
# ...

# %%
# multivariable analysis

selected_columns = ['SMOKING', 'FATIGUE ','COUGHING']
sns.pairplot(df[selected_columns], hue='AGE', palette = 'husl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-2c905a812f9b> in <cell line: 4>()
#       2
#       3 selected_columns = ['SMOKING', 'FATIGUE ','COUGHING']
# ----> 4 sns.pairplot(df[selected_columns], hue='AGE', palette = 'husl')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ...

# %%
df[selected_columns].corr()
sns.heatmap(df[selected_columns].corr(), annot=True, cmap='coolwarm', linewidth=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-67e7c0cee1b2> in <cell line: 1>()
# ----> 1 df[selected_columns].corr()
#       2 sns.heatmap(df[selected_columns].corr(), annot=True, cmap='coolwarm', linewidth=0.5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
# ...
